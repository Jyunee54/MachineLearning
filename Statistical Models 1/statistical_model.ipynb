# %%
from google.colab import drive
drive.mount("/gdrive", force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# !pip install hmmlearn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.4/160.4 kB 3.5 MB/s eta 0:00:00
# ...

# %%
import numpy as np
from hmmlearn import hmm

states = ["Rainy", "Sunny"]
n_states = len(states)

observations = ["Walk", "Shop", "Clean"]
n_observations = len(observations)

# 시작 확률
start_probability = np.array([0.6, 0.4])

# 전이 확률
transition_probability = np.array([
  [0.7, 0.3],
  [0.4, 0.6]
])

# 관측 확률
emission_probability = np.array([
  [0.1, 0.4, 0.5],
  [0.6, 0.3, 0.1]
])

# 모델 만들기
model = hmm.CategoricalHMM(n_components=n_states)
model.startprob_ = start_probability
model.transmat_ = transition_probability
model.emissionprob_ = emission_probability

# 관측 입력
input = [0, 0, 2, 1]

# HMM 모델 호출
hmm_input = np.atleast_2d(input).T
logprob, sequence = model.decode(hmm_input)

# 결과 출력
input_labels = [observations[x] for x in input]
output_labels = [states[x] for x in sequence]

print("Input :", ", ".join(input_labels))
print("Output:", ", ".join(output_labels))
print("Prob. :", logprob)
# Out:
# Input : Walk, Walk, Clean, Shop
# Output: Sunny, Sunny, Rainy, Rainy
# Prob. : -5.331171191419115
